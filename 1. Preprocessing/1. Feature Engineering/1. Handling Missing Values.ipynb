# %% [markdown]
# ### 🛠 Handling Missing Values
#
# Since the dataset might contains missing values, proper preprocessing techniques are applied to ensure data quality and model accuracy. Below are the steps used to handle missing values:
#
# #### 1️⃣ **Identify Missing Values**
# - Check for missing values using `isnull().sum()` in Pandas.
# - Visualize missing data patterns using a heatmap (`seaborn.heatmap`).
#
# #### 2️⃣ **Handling Strategies**
# Depending on the nature of missing data, different approaches are used:

# %%
### Importing Basic Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings("ignore")

# %%
## Loading Dataset
dataset = pd.read_csv("/home/ghost/Documents/Data Mining Mini Project/data/diabetes_data.csv")

# %%
## Checking first 5 lines of the dataset
dataset.head()
# Out:
#    Age Gender Polyuria Polydipsia sudden weight loss weakness Polyphagia  \
# 0   40   Male       No        Yes                 No      Yes         No
# 1   58   Male       No         No                 No      Yes         No
# 2   41   Male      Yes         No                 No      Yes        Yes
# 3   45   Male       No         No                Yes      Yes        Yes
# 4   60   Male      Yes        Yes                Yes      Yes        Yes
#
#   Genital thrush visual blurring Itching Irritability delayed healing  \
# 0             No              No     Yes           No             Yes
# 1             No             Yes      No           No              No
# 2             No              No     Yes           No             Yes
# 3            Yes              No     Yes           No             Yes
# 4             No             Yes     Yes          Yes             Yes
#
#   partial paresis muscle stiffness Alopecia Obesity     class
# ...

# %%
### check missing values
dataset.isnull()
# Out:
#        Age  Gender  Polyuria  Polydipsia  sudden weight loss  weakness  \
# 0    False   False     False       False               False     False
# 1    False   False     False       False               False     False
# 2    False   False     False       False               False     False
# 3    False   False     False       False               False     False
# 4    False   False     False       False               False     False
# ..     ...     ...       ...         ...                 ...       ...
# 515  False   False     False       False               False     False
# 516  False   False     False       False               False     False
# 517  False   False     False       False               False     False
# 518  False   False     False       False               False     False
# 519  False   False     False       False               False     False
#
#      Polyphagia  Genital thrush  visual blurring  Itching  Irritability  \
# ...

# %%
dataset.isnull().sum()
# Out:
# Age                   0
# Gender                0
# Polyuria              0
# Polydipsia            0
# sudden weight loss    0
# weakness              0
# Polyphagia            0
# Genital thrush        0
# visual blurring       0
# Itching               0
# Irritability          0
# delayed healing       0
# partial paresis       0
# muscle stiffness      0
# Alopecia              0
# Obesity               0
# class                 0
# dtype: int64

# %% [markdown]
# #### Observation: No Missing Values
